# %%
1. In the below elements which of them are values or an expression? eg:- values can be
integer or string and expressions will be mathematical operators.

* - Expression
& - Expression
-87.8 - Value
-  - Expression
/  - Expression
+ - Expression
6 - Value

# %%
2. What is the difference between string and variable?

String is a data type , While variable is something which store a  data temporarily and the values of valriable can change.

In Other words , 

Variable is a place where information is kept, while string is a type of information that is stored in variable

# %%
3. Describe three different data types.

Three different Data Types are 

Numeric  - Integer , Float , complex

Sequence Type - List , Tuple

Boolean - True , False

Integer Data Type - Reffered  as Integers or int class, Positive or negative whole numbers with no decimal points , Lent has no limit in this. e.g - 0 ,2 , -4355

Float Data Type - It is represented by float class.A real number with floating point representation & specified by a decimal point. e.g - 0.225 , 58 , -4.56

Complex Data type : This is represented by complex class. It is specified as (real part) + (imaginary part)j. e.g 9+5j

# %%
4. What is an expression made up of? What do all expressions do?

An expression is a combination of values, variables, operators, and calls to functions. e.g - Arithmetic Expression, Logical Expression, Relation Expressions

All Expressions produces a value, gives Output or return something after execution

# %%
5 .This assignment statements, like spam = 10. What is the difference between an expression and a statement?

Expressions always evalutes and gives a value/output or returns something after execution but 
statement  is just a single line entity or standalone unit which does what is said in that and doesn't return anything.

# %%
6. After running the following code, what does the variable bacon contain?
bacon = 22
bacon + 1 

The variable bacon contains the original value of 22

# %%
7. What should the values of the following two terms be?
'spam' + 'spamspam'
spam * 3

output : 'spamspamspam'

# %%
8. Why is eggs a valid variable name while 100 is invalid?

As per the variable naming rules , No variable can start with a number
Variable name should start with Alphabets(a-z /A-Z) or Underscore (_)

# %%
9. What three functions can be used to get the integer, floating-point number, or string
version of a value?

int() , float() , and str( ) functions

# %%
10. Why does this expression cause an error? How can you fix it?
'I have eaten' + 99 + 'burritos' 

Because we  can only concatenate str (not "int") to str.

we can fix this by adding quotes around 99 and using it as a string data type

'I have eaten' + ' 99 ' + 'burritos'
