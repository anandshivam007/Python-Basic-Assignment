# %%
1. What exactly is [] ?

[] is an empty list

# %% [raw]
#  2. In a list of values stored in a variable called spam, how would you assign the value 'hello' as the third value?
# (Assume [2, 4, 6, 8, 10] are in spam.)

# %%
spam = [2, 4, 6, 8, 10]
spam[2] = 'Hello'
spam
# Out:
# [2, 4, 'Hello', 8, 10]

# %%
Let's pretend the spam includes the list ['a', 'b', 'c', 'd'] for the next three queries.
3. What is the value of spam[int(int('3' * 2) / 11)]?
Ans :d 
4. What is the value of spam[-1]?
Ans : d
5. What is the value of spam[:2]?
Ans : ['a', 'b']

# %%
Let's pretend bacon has the list [3.14, 'cat', 11, 'cat', True ] for the next three questions.
6. What is the value of bacon.index('cat')? 
Ans : 1 
7. How does bacon.append(99) change the look of the list value in bacon?
Ans : [3.14, 'cat', 11, 'cat', True, 99]
8. How does bacon.remove('cat') change the look of the list in bacon?
Ans : [3.14, 11, 'cat', True, 99]

# %%
9. What are the list concatenation and list replication operators?

 Concatenation  +
    
 Replication    *

# %%
10. What is difference between the list methods append() and insert()?

In append() the element would be added to the end of the list by default whereas 
in insert() , we can add the element at the desired location by mentioning the index

# %%
11. What are the two methods for removing items from a list?

Two methods to remove items from list are pop and remove 
Pop will remove item from the end ,where as remove method can be used to remove the elements by specifying it.

# %%
12. Describe how list values and string values are identical.

Both  are ordered collections of characters, 
except that elements of a list can have any type and for any one list, the items can be of different types.

# %%
13. What is the difference between tuples and lists?

Tuples are immutable and lists are mutable , Also List uses [] , whereas tuples uses ()

# %%
14. How do you type a tuple value that only contains the integer 42?

# %%
a = (42,52)

# %%
15. How do you get a list value's tuple form? How do you get a tuple value's list form?

By passing list into the list() and passing the list in the Tuple()

# %%
16. Variables that "contain" list values are not necessarily lists themselves. Instead, what do they contain?

Reference to the list values

# %%
17. How do you distinguish between copy.copy() and copy.deepcopy()?

copy.deepcopy() will copy the nested list as well whereas the copy.copy() will copy only as single list
